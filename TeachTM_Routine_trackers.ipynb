# %% [markdown]
# <a href="https://colab.research.google.com/github/maxwellowusu/youthmappers_activities/blob/main/TeachTM_Routine_trackers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOT Routine trackers
#
# This codes analyses YouthMappers project activities in the HOT Tasking manager.
#
#
# Created by: Maxwell Owusu
#
# Spring 2022
#
# The George Washington University

# %%
# import libraries

import requests
import json
import pandas as pd
import numpy as np

from google.colab import drive
import sys

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Look for Organization ID. it is used for extracting inofmration about a specific organization 
url = 'https://tasking-manager-tm4-teachosm-api.hotosm.org/api/v2/organisations/?omitManagerList=false&omitOrgStats=true'
r = requests.get(url)
response = r.json()
response
# Out:
# {'organisations': [{'organisationId': 120,
#    'name': 'Aristotle University of Thessaloniki, Dept. of Primary Education',
#    'slug': 'aristotle-university-of-thessaloniki-dept-of-primary-education',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1647519165710_logoap8.JPG',
#    'description': None,
#    'url': 'https://www.eled.auth.gr/eng/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 127,
#    'name': 'Arizona State University',
#    'slug': 'arizona-state-university',
#    'logo': None,
#    'description': None,
#    'url': 'https://www.asu.edu/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 113,
#    'name': 'Bangladesh Open Innovation Lab (BOIL)',
#    'slug': 'bangladesh-open-innovation-lab-boil',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1628749799587_boil-logo-new.png',
#    'description': 'Our aim is to build a community that supports the Open Data and uptake of the Living Lab paradigm. Empowering everyone to innovate BOIL focuses on collecting information and achieved experience on community issues all over Bangladesh and brings the information on the open platform in a spatial and non-spatial manner to enhance the coordination among the concerned agencies as well as the cross-boundary. To organize training on OpenStreetMap, QGIS, GeoNode, Open Layers, Carto in an integrated approach for addressing and solving community issues such as (a) Tagging and mapping the vulnerable communities through OpenStreetMap; (b) Pre-disaster mapping in pro-poor communities; (c) Disaster response initiative by open data; (d) Strengthening the community through ICT knowledge;(e) Training on object-oriented data analysis and visualization and (f) Hands-on training on bridging data portals. It provides consultancy and support in the field of education, training, data mining data management, digital innovation and Information technology-based solution, research, etc. & assists the smooth implementation of different kinds of development projects.',
#    'url': 'https://boiledbhoot.org/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 102,
#    'name': 'California University of Pennsylvania',
#    'slug': 'california-university-of-pennsylvania',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1611094456251_calu19.png',
#    'description': 'California University of Pennsylvania is located near Pittsburgh, PA. Cal U offers career-focused academic programs that engage students in applied and active learning. ',
#    'url': 'https://www.calu.edu/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 106,
#    'name': 'Code for Charlottesville',
#    'slug': 'code-for-charlottesville',
#    'logo': None,
#    'description': None,
#    'url': 'codeforcville.org',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 110,
#    'name': 'CrisisMappers Japan, NPO',
#    'slug': 'crisismappers-japan-npo',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1630462476335_crisismappersjapandronebirdlogosqw400xh400.png',
#    'description': 'The purpose of this organization is to contribute to the promotion of informatization in the field of school education and in general society by conducting projects for educational institutions and the general public, focusing on crisis mapping activities to quickly create and share map information in the event of natural disasters, riots, political turmoil, and other crisis situations.\n\nこの法人は教育機関及び一般市民に対して、自然災害、暴動、政治的混乱、その他の危機的な状況下において、地図情報を迅速に作成・共有するクライシスマッピング活動を中心とした事業を行い、学校教育分野、一般社会における情報化の推進に寄与することを目的とする。',
#    'url': 'http://crisismappers.jp/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 131,
#    'name': 'Fredonia SUNY',
#    'slug': 'fredonia-suny',
#    'logo': None,
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 109,
#    'name': 'Furuhashi Laboratory, Aoyama Gakuin University',
#    'slug': 'furuhashi-laboratory-aoyama-gakuin-university',
#    'logo': None,
#    'description': None,
#    'url': 'http://furuhashilab.com/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 124,
#    'name': 'Iowa State University Mappers',
#    'slug': 'iowa-state-university-mappers',
#    'logo': None,
#    'description': 'Iowa State University ',
#    'url': 'https://www.design.iastate.edu/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 123,
#    'name': 'IowaView',
#    'slug': 'iowaview',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1656534539638_iowaview.jpg',
#    'description': 'IowaView is a program dedicated to providing research, education, and outreach in the areas of remote sensing and geospatial technology and promoting remote sensing imagery and data resources.  IowaView is part of the nationwide AmericaView partnership of remote sensing scientists who support the use of Landsat and other public domain remotely sensing data through applied remote sensing research, K-12, and higher STEM education. workforce development. and technology transfer.',
#    'url': 'https://www.iowaview.org/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 119,
#    'name': 'Map4SaintLucia',
#    'slug': 'mapsaintlucia',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1645464306271_logomapsaintlucialarge.png',
#    'description': 'The OpenStreetMapping community in Saint Lucia.',
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 112,
#    'name': 'MapBD',
#    'slug': 'dhaka-college',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1628504649893_mapbd.png',
#    'description': None,
#    'url': 'https://mapbd.github.io/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 108,
#    'name': 'Mapeadores Livres - UFPR',
#    'slug': 'mapeadores-livres-ufpr-chapter-of-youthmappers',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1620945947591_mapealivrelogo.jpg',
#    'description': 'UFPR chapter of YouthMappers',
#    'url': 'https://twitter.com/MapeaLivreUFPR',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 115,
#    'name': 'MaptimeBmore',
#    'slug': 'maptimebmore',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1629397108901_qtqpzk9d400x400.jpg',
#    'description': None,
#    'url': 'http://maptime.io/baltimore/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 130,
#    'name': 'Mashpee High School',
#    'slug': 'mashpee-high-school',
#    'logo': None,
#    'description': None,
#    'url': 'https://www.mpspk12.org/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 128,
#    'name': 'Northern Virginia Community College',
#    'slug': 'northern-virginia-community-college',
#    'logo': None,
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 129,
#    'name': 'Northville Central School',
#    'slug': 'northville-central-school',
#    'logo': None,
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 126,
#    'name': 'Northville School District',
#    'slug': 'northville-school-district',
#    'logo': None,
#    'description': None,
#    'url': 'https://northvilecsd.org',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 114,
#    'name': 'OpenStreetMap Nigeria',
#    'slug': 'opensteetmap-nigeria',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1628797662879_104910965429400624956517151316639142534314n.png',
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 111,
#    'name': 'OpenStreetMap US',
#    'slug': 'openstreetmap-us',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1626293175434_osmus-logo.png',
#    'description': None,
#    'url': 'openstreetmap.us',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 122,
#    'name': 'OSM Bouaké',
#    'slug': 'osm-bouake',
#    'logo': None,
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 105,
#    'name': 'PoliMappers',
#    'slug': 'polimappers',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1615109689929_logo.png',
#    'description': "PoliMappers is a volunteer students' group, based at Politecnico di Milano, created in December 2016. The mission of the group is to train and motivate the next generation of volunteer mappers and to do mapping using free and open source software within the university as well as primary and secondary schools.\n\nPoliMappers is the first European chapter of the international association YouthMappers.",
#    'url': 'https://polimappers.github.io/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 104,
#    'name': 'Politecnico di Milano - GEOLab',
#    'slug': 'politecnico-di-milano-geolab',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1615109398745_logogeolabdefb-976x1024.jpg',
#    'description': 'GEOlab is a multidisciplinary research laboratory whose focus is on the collection, modeling, analysis and representation of Earth observations.The lab activities include the assessment of the strategic and business impact of Earth Observation applications and services within the “Space Economy” framework.\nDesktop and web-based GIS for geo-referenced data manipulation, sharing and visualization with the forefront aspects of citizen science are a main research topic for the group as well.',
#    'url': 'http://www.geolab.polimi.it/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 1,
#    'name': 'TeachOSM',
#    'slug': 'teachosm',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1618823381821_teachosmlogo.png',
#    'description': 'Putting open mapping in education.',
#    'url': 'https://teachosm.org',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 116,
#    'name': 'Texas Tech YouthMappers',
#    'slug': 'lubbock-compact',
#    'logo': None,
#    'description': 'The YouthMappers Chapter of Texas Tech University',
#    'url': 'https://www.twitch.tv/ttugeography',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 118,
#    'name': 'The University of Sydney',
#    'slug': 'university-of-sydney',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1630917760460_u-of-sydney.jpeg',
#    'description': None,
#    'url': 'https://www.sydney.edu.au/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 121,
#    'name': 'Univerisdad de Cuenca',
#    'slug': 'univerisdad-de-cuenca',
#    'logo': None,
#    'description': 'Univerisdad de Cuenca Ecuador',
#    'url': 'https://www.ucuenca.edu.ec/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 107,
#    'name': 'USDOT',
#    'slug': 'usdot',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1617119052406_logous-dot-logo.jpg',
#    'description': 'United States Department of Transportation',
#    'url': 'https://www.transportation.gov/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 125,
#    'name': 'USTP-AGES Youthmappers Chapter',
#    'slug': 'ustp-ages-youthmappers-chapter',
#    'logo': None,
#    'description': None,
#    'url': None,
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 103,
#    'name': 'YouthMappers',
#    'slug': 'youthmappers',
#    'logo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'description': None,
#    'url': 'https://www.youthmappers.org/',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None},
#   {'organisationId': 117,
#    'name': 'YouthMappers Patanal',
#    'slug': 'youthmappers-patanal',
#    'logo': None,
#    'description': 'YouthMappers Chapter Pantanal',
#    'url': 'ufms.br',
#    'isManager': None,
#    'teams': None,
#    'campaigns': None,
#    'type': 'FREE',
#    'subscriptionTier': None}]}

# %%
# Setup HOT-TM to download YouthMappers activities 
apiKey='Token asdgshswrthdhsdfghbtdhasertsb'
hasNext=True
results = []
page = 1
# http://tasking-manager-tm4-teachosm-api.hotosm.org
while hasNext:
    payload = {'organisationId': 103, 'page': page, 'projectStatuses': 'PUBLISHED,ARCHIVED' }
    # payload = {'organisationId': 103, }
    headers = {'Authorization': 'apiKey'}
    r = requests.get("http://tasking-manager-tm4-teachosm-api.hotosm.org/api/v2/projects/", params=payload, headers=headers)
    response = r.json()
    response['pagination']['page']
    results.append(response)
    if response['pagination']['hasNext']:
        page = response['pagination']['nextNum']
    else:
        hasNext=False

# %%
results[1]
# Out:
# {'mapResults': {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [5.09615358031053, 7.00111428252418]},
#     'properties': {'projectId': 1272, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-10.5743056682585, 8.27667609793703]},
#     'properties': {'projectId': 1316, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-10.9669265668683, 8.63937321337854]},
#     'properties': {'projectId': 1320, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-10.3368491755362, 8.46032831907738]},
#     'properties': {'projectId': 1321, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-10.9254510362024, 7.94759439764406]},
#     'properties': {'projectId': 1322, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.2550155396695, 8.28359642576657]},
#     'properties': {'projectId': 1323, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-13.0160191114747, 8.33388453700628]},
#     'properties': {'projectId': 1324, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-13.1364965845327, 8.4038336925489]},
#     'properties': {'projectId': 1325, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-13.2240246139477, 8.64653499059857]},
#     'properties': {'projectId': 1326, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-11.7492761940066, 9.04391975900004]},
#     'properties': {'projectId': 1327, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.0468998868531, 8.88348608848173]},
#     'properties': {'projectId': 1328, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-11.9410234528459, 8.71924757090397]},
#     'properties': {'projectId': 1331, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.7814402042235, 8.7710651198125]},
#     'properties': {'projectId': 1332, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.9195827229068, 9.11488529097222]},
#     'properties': {'projectId': 1333, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.2393271018433, 9.4992022644727]},
#     'properties': {'projectId': 1334, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.507123217185, 7.52770090563596]},
#     'properties': {'projectId': 1335, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.1737192976674, 7.60544792628444]},
#     'properties': {'projectId': 1336, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-12.4301066876995, 8.16085683891724]},
#     'properties': {'projectId': 1337, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-11.7247834284983, 7.35884055216175]},
#     'properties': {'projectId': 1338, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.749846456535, -16.7926417639837]},
#     'properties': {'projectId': 1439, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [177.080375035856, -12.503165337352]},
#     'properties': {'projectId': 1440, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [179.847593709527, -18.7779671161178]},
#     'properties': {'projectId': 1442, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-178.978449169586, -18.2155909105108]},
#     'properties': {'projectId': 1444, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.247348952727, -19.0314312103453]},
#     'properties': {'projectId': 1445, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [179.166246702617, -17.7088382624875]},
#     'properties': {'projectId': 1446, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.234323626268, -17.8672151687026]},
#     'properties': {'projectId': 1447, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.113744072527, -18.0647003869987]},
#     'properties': {'projectId': 1448, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.420199519795, -18.1118847613252]},
#     'properties': {'projectId': 1449, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [177.955616054555, -18.1548821263807]},
#     'properties': {'projectId': 1450, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.487822293913, -17.798756230303]},
#     'properties': {'projectId': 1451, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [179.541433826806, -16.6331221081096]},
#     'properties': {'projectId': 1452, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-179.905190545386, -16.7046150772393]},
#     'properties': {'projectId': 1453, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [179.294078797511, -16.4638201151147]},
#     'properties': {'projectId': 1454, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [177.659750187052, -17.6334059091799]},
#     'properties': {'projectId': 1455, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [177.661999811415, -17.9852727552298]},
#     'properties': {'projectId': 1456, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [178.189925296666, -17.5232582199987]},
#     'properties': {'projectId': 1457, 'priority': 'URGENT'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-112.014040951462, 33.4758494208625]},
#     'properties': {'projectId': 1401, 'priority': 'HIGH'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [39.5222613798105, 9.67383805489933]},
#     'properties': {'projectId': 1247, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [0.010778170412607, 5.74191445426093]},
#     'properties': {'projectId': 1249, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [30.0392514391106, -1.26064386521978]},
#     'properties': {'projectId': 1301, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [33.0878703282004, 3.42880020407136]},
#     'properties': {'projectId': 1302, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [33.8500295821907, 1.43830613766607]},
#     'properties': {'projectId': 1312, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [0.036844584178082, 5.73592629846469]},
#     'properties': {'projectId': 1344, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [28.4083437308073, -25.7223057238915]},
#     'properties': {'projectId': 1346, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-76.7373203568575, 8.0931607785659]},
#     'properties': {'projectId': 1355, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-2.70729312096326, 10.540193646286]},
#     'properties': {'projectId': 1373, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-2.02274894329202, 5.15377657631532]},
#     'properties': {'projectId': 1378, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-1.35169491494766, 5.08706718913203]},
#     'properties': {'projectId': 1391, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-111.628110770736, 33.4153695538492]},
#     'properties': {'projectId': 1402, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [15.37696568826, -4.117959813968]},
#     'properties': {'projectId': 1470, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [4.53398970239341, 7.49480401083254]},
#     'properties': {'projectId': 1482, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-80.5296273594257, 7.31574375655129]},
#     'properties': {'projectId': 1484, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-80.4556774095554, 7.40336177942723]},
#     'properties': {'projectId': 1486, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-98.2700773789349, 26.1171706476886]},
#     'properties': {'projectId': 1494, 'priority': 'MEDIUM'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-73.921098275038, 41.6948964363702]},
#     'properties': {'projectId': 1225, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [5.11696823000512, 7.11370325725439]},
#     'properties': {'projectId': 1242, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [45.2884990340592, 2.03850153402223]},
#     'properties': {'projectId': 1243, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-74.9976676287629, 8.33002660351408]},
#     'properties': {'projectId': 1275, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-75.5832167308183, 6.27162261465973]},
#     'properties': {'projectId': 1392, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-112.169902661396, 33.4660359689606]},
#     'properties': {'projectId': 1400, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-68.172913547764, -16.4564536711287]},
#     'properties': {'projectId': 1461, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-46.4117008247952, -19.1734384901035]},
#     'properties': {'projectId': 1463, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [29.7417274421923, -23.8903603673949]},
#     'properties': {'projectId': 1472, 'priority': 'LOW'}},
#    {'type': 'Feature',
#     'geometry': {'type': 'Point',
#      'coordinates': [-48.3712770427812, -18.969022240981]},
#     'properties': {'projectId': 1488, 'priority': 'LOW'}}]},
#  'results': [{'projectId': 1334,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN SIERRA LEONE – KAMAKWIE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 100,
#    'percentValidated': 96,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-11T17:51:46.530068Z',
#    'dueDate': None,
#    'totalContributors': 20,
#    'country': ['Sierra Leone']},
#   {'projectId': 1335,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN SIERRA LEONE – BONTHE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-10-11T19:19:28.977806Z',
#    'dueDate': None,
#    'totalContributors': 18,
#    'country': ['Sierra Leone']},
#   {'projectId': 1336,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN SIERRA LEONE – MATTRU JONG',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': -3,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-11-14T14:58:58.637035Z',
#    'dueDate': None,
#    'totalContributors': 35,
#    'country': ['Sierra Leone']},
#   {'projectId': 1337,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN SIERRA LEONE – MOYAMBA',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 100,
#    'percentValidated': 100,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-06-15T18:04:12.368986Z',
#    'dueDate': None,
#    'totalContributors': 55,
#    'country': ['Sierra Leone']},
#   {'projectId': 1338,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN SIERRA LEONE – PUJEHUN',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 96,
#    'percentValidated': 100,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-06T23:09:01.729855Z',
#    'dueDate': None,
#    'totalContributors': 41,
#    'country': ['Sierra Leone']},
#   {'projectId': 1439,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – BAU PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 10,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-11-04T19:59:36.306105Z',
#    'dueDate': None,
#    'totalContributors': 8,
#    'country': ['Fiji']},
#   {'projectId': 1440,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – ROTUMA',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 8,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-11-23T12:04:20.876931Z',
#    'dueDate': None,
#    'totalContributors': 4,
#    'country': ['Fiji']},
#   {'projectId': 1442,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – LAU PROVINCE 2',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-14T19:49:24.732433Z',
#    'dueDate': None,
#    'totalContributors': 1,
#    'country': ['Fiji']},
#   {'projectId': 1444,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – LAU PROVINCE 1',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-14T19:49:19.036477Z',
#    'dueDate': None,
#    'totalContributors': 0,
#    'country': ['Fiji']},
#   {'projectId': 1445,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – KADAVU PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-14T19:49:12.311196Z',
#    'dueDate': None,
#    'totalContributors': 5,
#    'country': ['Fiji']},
#   {'projectId': 1446,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – LOMAIVITI PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 0,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-07-14T19:49:06.876923Z',
#    'dueDate': None,
#    'totalContributors': 2,
#    'country': ['Fiji']},
#   {'projectId': 1447,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – NAITASIRI PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 90,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-12-08T00:53:22.377509Z',
#    'dueDate': '2023-01-31T07:00:00.000000Z',
#    'totalContributors': 43,
#    'country': ['Fiji']},
#   {'projectId': 1448,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – NAMOSI PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 35,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-12-08T18:47:23.968974Z',
#    'dueDate': None,
#    'totalContributors': 9,
#    'country': ['Fiji']},
#   {'projectId': 1449,
#    'locale': 'en',
#    'name': 'MAPPING POWER IN FIJI – REWA PROVINCE',
#    'shortDescription': 'Many rural villages and communities struggle with access to reliable electricity and power. Access to reliable energy is important for women and girls. YouthMappers chapters are teaming up to map buildings and roads to properly design power distribution networks.',
#    'mapperLevel': 'BEGINNER',
#    'priority': 'URGENT',
#    'organisationName': 'YouthMappers',
#    'organisationLogo': 'https://cdn.hotosm.org/tasking-manager/uploads/1612967434586_mwb-hires.png',
#    'campaigns': [],
#    'percentMapped': 32,
#    'percentValidated': 0,
#    'status': 'PUBLISHED',
#    'activeMappers': 0,
#    'lastUpdated': '2022-12-01T02:27:21.539652Z',
#    'dueDate': None,
#    'totalContributors': 8,
#    'country': ['Fiji']}],
#  'pagination': {'hasNext': True,
#   'hasPrev': True,
#   'nextNum': 3,
#   'page': 2,
#   'pages': 5,
#   'prevNum': 1,
#   'perPage': 14,
#   'total': 64}}

# %%
# Get the list of YM project IDs

# rows list initialization
projectsID = []
status = []
percentMapped = []
percentValidated = []
organisationName = []
lastUpdated = []
name = []
country = []
# appending rows
for data in results:
    data_row = data['results']
    # print (data_row)

    for row in data_row:
        row= row['projectId']
        projectsID.append(row)

    for row in data_row:
        row= row['status']
        status.append(row)

    for row in data_row:
        row= row['percentMapped']
        percentMapped.append(row)

    for row in data_row:
        row= row['percentValidated']
        percentValidated.append(row)

    for row in data_row:
        row= row['organisationName']
        organisationName.append(row)

    for row in data_row:
        row= row['lastUpdated']
        lastUpdated.append(row)

    for row in data_row:
        row= row['name']
        name.append(row)

    for row in data_row:
        row= row['country']
        country.append(row)
# create a list to selected features

df_list = {"projectsID": projectsID, "status": status, "name":name, "country":country, "percentMapped": percentMapped, "percentValidated": percentValidated, "organisationName": organisationName, "lastUpdated": lastUpdated}
# convert list to dataframe
df = pd.DataFrame(df_list)
print(df.shape)
df.head(100)
# Out:
# (64, 8)
#     projectsID     status                                               name  \
# 0         1272  PUBLISHED  MAPPING POWER IN NIGERIA -  IWONJA-IROWA COMMU...
# 1         1316  PUBLISHED           MAPPING POWER IN SIERRA LEONE – KAILAHUN
# 2         1320  PUBLISHED              MAPPING POWER IN SIERRA LEONE – KOIDU
# 3         1321  PUBLISHED             MAPPING POWER IN SIERRA LEONE – KOINDU
# 4         1322  PUBLISHED           MAPPING POWER IN SIERRA LEONE – PENDEMBU
# ..         ...        ...                                                ...
# 59        1400  PUBLISHED                    Pedestrian Safety at Crosswalks
# 60        1461  PUBLISHED  Mapatón #1 UMSA 2022 - Barrios de Santa Rosa d...
# 61        1463  PUBLISHED  Mapeamento das Edificações e Estradas Rurais n...
# 62        1472  PUBLISHED               University of Limpopo Campus Mapping
# 63        1488  PUBLISHED  UFU-Mappers: Mapeamento das Edificações em Ube...
#
#             country  percentMapped  percentValidated organisationName  \
# 0         [Nigeria]              0               -84     YouthMappers
# 1    [Sierra Leone]              0                 0     YouthMappers
# 2    [Sierra Leone]             99               100     YouthMappers
# 3    [Sierra Leone]              0                 0     YouthMappers
# 4    [Sierra Leone]              0                 0     YouthMappers
# ..              ...            ...               ...              ...
# 59  [United States]             28                 2     YouthMappers
# 60        [Bolivia]             32                 7     YouthMappers
# 61         [Brazil]              9                 0     YouthMappers
# 62   [South Africa]             80                 0     YouthMappers
# 63         [Brazil]             10                 0     YouthMappers
#
#                     lastUpdated
# 0   2022-12-01T21:59:08.558321Z
# 1   2022-11-30T21:20:11.419882Z
# 2   2022-08-17T01:55:39.829499Z
# 3   2022-10-11T19:18:19.735352Z
# 4   2022-10-11T19:18:38.442490Z
# ..                          ...
# 59  2022-05-12T14:39:47.320031Z
# 60  2022-08-18T11:53:03.751709Z
# 61  2022-10-20T22:05:33.161410Z
# 62  2022-11-11T09:58:34.381122Z
# 63  2022-11-28T19:24:57.724320Z
#
# [64 rows x 8 columns]

# %%
projectIds = []
YM_contributions_results = []
project_ids = df["projectsID"].values
hot_base_url = 'https://tasking-manager-tm4-teachosm-api.hotosm.org'

# Retrieve relevant project meta data information via HOT Tasking Manager API
# https://tasking-manager-tm4-production-api.hotosm.org/api/v2/projects/1234/

for project_id in project_ids:
  project_api_endpoint = f'{hot_base_url}/api/v2/projects/{project_id}/'
  project_info = requests.get(project_api_endpoint).json()
  YM_contributions_results.append({project_id : project_info})
  # projectIds.append({"projectid": project_id})

print(len(YM_contributions_results))
# Out:
# 64

# %%
# rows list initialization
name = []
username = []
mappingLevel = []
mapped = []  
validated =[]
total = []
projectIds = []
created = []
# appending rows

for data in YM_contributions_results:
  # print (data)
  for p_id, p_info in data.items():
    projectIds.append(p_id)
    data_row = p_info['created']
    created.append(data_row)
    # print (data_row)



print(len(projectIds))
print(len(created))

df_list = {"projectsid": projectIds, "created": created}
# convert list to dataframe
df1 = pd.DataFrame(df_list)
print(df1.shape)
# df1.head(10)
# Out:
# 64
# 64
# (64, 2)

# %%
# Merge data
df_full  = pd.concat([df,df1], axis=1)

# %%
df_full['date_created'] = df_full['created'].apply(pd.to_datetime)
df_full['date'] = pd.to_datetime(df_full['created']).dt.date
df_full.sort_values(by='date', ascending=False, inplace=True)
df_full.drop(['date_created', 'created', 'projectsid'], axis=1, inplace=True)
df_full.head(15)
# Out:
#     projectsID     status                                               name  \
# 53        1494  PUBLISHED  Geographies of Migration – Mapping Border Infr...
# 63        1488  PUBLISHED  UFU-Mappers: Mapeamento das Edificações em Ube...
# 52        1486  PUBLISHED   Proyecto de Reciclaje en el Municipio de Tono...
# 51        1484  PUBLISHED   Proyecto de Reciclaje en el Municipio de Tono...
# 50        1482  PUBLISHED  Mapping Buildings in the Surrounding OAU Commu...
# 62        1472  PUBLISHED               University of Limpopo Campus Mapping
# 49        1470  PUBLISHED                 Mapathon de la commune de Kintélé
# 61        1463  PUBLISHED  Mapeamento das Edificações e Estradas Rurais n...
# 60        1461  PUBLISHED  Mapatón #1 UMSA 2022 - Barrios de Santa Rosa d...
# 29        1451  PUBLISHED           MAPPING POWER IN FIJI – TAILEVU PROVINCE
# 24        1446  PUBLISHED         MAPPING POWER IN FIJI – LOMAIVITI PROVINCE
# 25        1447  PUBLISHED         MAPPING POWER IN FIJI – NAITASIRI PROVINCE
# 26        1448  PUBLISHED            MAPPING POWER IN FIJI – NAMOSI PROVINCE
# 27        1449  PUBLISHED              MAPPING POWER IN FIJI – REWA PROVINCE
# 28        1450  PUBLISHED             MAPPING POWER IN FIJI – SERUA PROVINCE
#
#                 country  percentMapped  percentValidated organisationName  \
# 53      [United States]             72                 0     YouthMappers
# 63             [Brazil]             10                 0     YouthMappers
# 52             [Panama]            100                 0     YouthMappers
# 51             [Panama]            100                 0     YouthMappers
# 50            [Nigeria]              4                 0     YouthMappers
# 62       [South Africa]             80                 0     YouthMappers
# 49  [Congo-Brazzaville]             48                11     YouthMappers
# 61             [Brazil]              9                 0     YouthMappers
# 60            [Bolivia]             32                 7     YouthMappers
# 29               [Fiji]              0                 0     YouthMappers
# 24               [Fiji]              0                 0     YouthMappers
# 25               [Fiji]             90                 0     YouthMappers
# 26               [Fiji]             35                 0     YouthMappers
# 27               [Fiji]             32                 0     YouthMappers
# 28               [Fiji]              2                 0     YouthMappers
#
#                     lastUpdated        date
# 53  2022-12-08T01:55:26.359536Z  2022-12-06
# 63  2022-11-28T19:24:57.724320Z  2022-11-01
# 52  2022-11-28T23:56:51.577716Z  2022-10-21
# 51  2022-11-25T01:23:14.093316Z  2022-10-14
# 50  2022-12-02T12:22:02.189926Z  2022-10-13
# 62  2022-11-11T09:58:34.381122Z  2022-09-06
# 49  2022-12-07T13:11:00.927484Z  2022-08-08
# 61  2022-10-20T22:05:33.161410Z  2022-08-02
# 60  2022-08-18T11:53:03.751709Z  2022-07-21
# 29  2022-07-14T19:48:18.345263Z  2022-06-23
# 24  2022-07-14T19:49:06.876923Z  2022-06-23
# 25  2022-12-08T00:53:22.377509Z  2022-06-23
# 26  2022-12-08T18:47:23.968974Z  2022-06-23
# 27  2022-12-01T02:27:21.539652Z  2022-06-23
# 28  2022-12-01T03:01:36.322107Z  2022-06-23

# %%
# Make directory
import os

OUTPUT_PATH = "/content/drive/MyDrive/Colab Notebooks/youthmappers/output"
directory = os.path.dirname(OUTPUT_PATH)
if not os.path.exists(directory):
    os.makedirs(directory)

# %%
# Save results to csv
df_full.to_csv(f'{OUTPUT_PATH}/TMresults.csv')
